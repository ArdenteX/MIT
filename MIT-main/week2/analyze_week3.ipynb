# %%
from pyecharts.charts import Line
from pyecharts.charts import Bar
from pyecharts.charts import Grid
from analyze_week_3 import AnalyzeDeath
from analyze_week_3 import deathRate, AsymptomaticRate
import pandas as pd
import pyecharts.options as opts

# %%
file_path = 'D:\\广商网课\\resource\\Covid-19-result\\death\\'
file_As = 'D:\\广商网课\\resource\\Covid-19-result\\Asymptomatic\\'

# %%
analyze = AnalyzeDeath()

# %%
data, intervals = analyze.convert_data()

# %%
data
# Out:
# {'case_month': ['2020-01-01',
#   '2020-02-01',
#   '2020-03-01',
#   '2020-04-01',
#   '2020-05-01',
#   '2020-06-01',
#   '2020-07-01',
#   '2020-08-01',
#   '2020-09-01',
#   '2020-10-01',
#   '2020-11-01',
#   '2020-12-01',
#   '2021-01-01',
#   '2021-02-01',
#   '2021-03-01',
#   '2021-04-01',
#   '2021-05-01',
#   '2021-06-01',
#   '2021-07-01',
#   '2021-08-01',
#   '2021-09-01',
#   '2021-10-01',
#   '2021-11-01',
#   '2021-12-01',
#   '2022-01-01',
#   '2022-02-01',
#   '2022-03-01',
#   '2022-04-01'],
#  'count': [302,
#   40,
#   6469,
#   16860,
#   5086,
#   3373,
#   6406,
#   3227,
#   2116,
#   4567,
#   11150,
#   22404,
#   13547,
#   3158,
#   1336,
#   1250,
#   428,
#   233,
#   2277,
#   6147,
#   3727,
#   2337,
#   3525,
#   9065,
#   14113,
#   1715,
#   319,
#   22]}

# %%
data_x = data['case_month']
data_y = data['count']

# %%
c = (
    Line()
    .add_xaxis(data_x)
    .add_yaxis("Case", data_y, is_connect_nones=True)
    .set_global_opts(
        xaxis_opts={
             'type': 'category',
             'data': data_x
        },
        title_opts={
            'text': 'Death_Case Date',
            'left': '1%'
        },
        tooltip_opts={
             'trigger': 'axis'
        },
        toolbox_opts={
            'right': 10,
            'feature': {
              'dataZoom': {
                'yAxisIndex': 'none'
              },
              'restore': {},
              'saveAsImage': {}
            }
        },
        datazoom_opts=[
            {
              'startValue': '2020-01-01'
            },
            {
              'type': 'inside'
            }
        ],
        visualmap_opts={
            'top': 50,
            'right': 10,
            'pieces': [
              {
                'gt': 0,
                'lte': intervals[0],
                'color': '#93CE07'
              },
              {
                'gt': intervals[0],
                'lte': intervals[1],
                'color': '#FBDB0F'
              },
              {
                'gt': intervals[1],
                'lte': intervals[2],
                'color': '#FC7D02'
              },
              {
                'gt': intervals[2],
                'lte': intervals[3],
                'color': '#FD0100'
              },
              {
                'gt': intervals[3],
                'lte': intervals[4],
                'color': '#AA069F'
              },
              {
                'gt': intervals[4],
                'color': '#AC3B2A'
              }
            ],
            'outOfRange': {
              'color': '#999'
            }
        },
                    
    )

)

# %%
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c68306fe14e745edb3cd5b64e373b129" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c68306fe14e745edb3cd5b64e373b129 = echarts.init(
#                     document.getElementById('c68306fe14e745edb3cd5b64e373b129'), 'white', {renderer: 'canvas'});
#                 var option_c68306fe14e745edb3cd5b64e373b129 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
d_r = deathRate()

# %%
d_r.convert_data()
# Out:
# ({'case_month': ['2020-01-01',
#    '2020-02-01',
#    '2020-03-01',
#    '2020-04-01',
#    '2020-05-01',
#    '2020-06-01',
#    '2020-07-01',
#    '2020-08-01',
#    '2020-09-01',
#    '2020-10-01',
#    '2020-11-01',
#    '2020-12-01',
#    '2021-01-01',
#    '2021-02-01',
#    '2021-03-01',
#    '2021-04-01',
#    '2021-05-01',
#    '2021-06-01',
#    '2021-07-01',
#    '2021-08-01',
#    '2021-09-01',
#    '2021-10-01',
#    '2021-11-01',
#    '2021-12-01',
#    '2022-01-01',
#    '2022-02-01',
#    '2022-03-01',
#    '2022-04-01'],
#   'rate': [21.99563000728332,
#    3.92156862745098,
#    14.089077643471631,
#    18.683924732374383,
#    5.827489802465741,
#    3.085691284500188,
#    4.107726835524207,
#    2.810804219254923,
#    1.8986773863575184,
#    2.32172723898997,
#    3.0730983997839187,
#    5.494179416690986,
#    3.7772306628486345,
#    2.189649434213446,
#    0.8643277199474676,
#    1.0157976856065531,
#    0.670405062498042,
#    0.7397999682489285,
# ...

# %%
data_line, data_bar = d_r.convert_data()

for i in range(len(data_line['rate'])):
    data_line['rate'][i] = round(data_line['rate'][i], 2)

# %%
data_line
# Out:
# {'case_month': ['2020-01-01',
#   '2020-02-01',
#   '2020-03-01',
#   '2020-04-01',
#   '2020-05-01',
#   '2020-06-01',
#   '2020-07-01',
#   '2020-08-01',
#   '2020-09-01',
#   '2020-10-01',
#   '2020-11-01',
#   '2020-12-01',
#   '2021-01-01',
#   '2021-02-01',
#   '2021-03-01',
#   '2021-04-01',
#   '2021-05-01',
#   '2021-06-01',
#   '2021-07-01',
#   '2021-08-01',
#   '2021-09-01',
#   '2021-10-01',
#   '2021-11-01',
#   '2021-12-01',
#   '2022-01-01',
#   '2022-02-01',
#   '2022-03-01',
#   '2022-04-01'],
#  'rate': [22.0,
#   3.92,
#   14.09,
#   18.68,
#   5.83,
#   3.09,
#   4.11,
#   2.81,
#   1.9,
#   2.32,
#   3.07,
#   5.49,
#   3.78,
#   2.19,
#   0.86,
#   1.02,
#   0.67,
#   0.74,
#   2.15,
#   2.19,
#   1.39,
#   1.33,
#   1.75,
#   2.07,
#   1.68,
#   1.2,
#   0.87,
#   0.11]}

# %%
b = (
    Bar()
    .add_xaxis(list(data_bar['case_month']))
    .add_yaxis('Confirmed Case', list(data_bar['count']), yaxis_index=0)
    .extend_axis(
        yaxis=opts.AxisOpts(
            name="Death Rate",
            min_=-3,
            max_=max(data_line['rate']),
            position="left",

            axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(color="#675bba")
            ),
            axislabel_opts=opts.LabelOpts(formatter="{value}%"),
            splitline_opts=opts.SplitLineOpts(
                is_show=True, linestyle_opts=opts.LineStyleOpts(opacity=1)
            ),
        ),
    )
    .set_global_opts(
        title_opts={
            'text': 'Death Rate & Confirmed Case'
        },
        yaxis_opts=opts.AxisOpts(
            name="Confirmed Case",
            min_=0,
            max_=max(data_bar['count']),
            position="right",

            axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(color="#d14a61")
            ),
            axislabel_opts=opts.LabelOpts(formatter="{value}"),
        ),
        tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross"),
        
    )
    
)

# %%
b.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c6a84f83e46b49e2bdf69cc43cd446ff" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c6a84f83e46b49e2bdf69cc43cd446ff = echarts.init(
#                     document.getElementById('c6a84f83e46b49e2bdf69cc43cd446ff'), 'white', {renderer: 'canvas'});
#                 var option_c6a84f83e46b49e2bdf69cc43cd446ff = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
line = (
    Line()
    .add_xaxis(list(data_line['case_month']))
    .add_yaxis(
        "Death Rate",
        list(data_line['rate']),
        yaxis_index=1,
        color="#675bba",
        label_opts=opts.LabelOpts(is_show=False),
    )
)

# %%
b.overlap(line)
grid = Grid()
grid.add(b, opts.GridOpts(pos_left="5%", pos_right="20%"), is_control_axis_index=True)

# %%
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="38c15e71c71e44b8a388aab0540530fb" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_38c15e71c71e44b8a388aab0540530fb = echarts.init(
#                     document.getElementById('38c15e71c71e44b8a388aab0540530fb'), 'white', {renderer: 'canvas'});
#                 var option_38c15e71c71e44b8a388aab0540530fb = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
as_ = AsymptomaticRate()

# %%
as_data = as_.convert_data()

for i in range(len(as_data['rate'])):
    as_data['rate'][i] = round(as_data['rate'][i], 2)

# %%
as_data
# Out:
# {'case_month': ['2020-01-01',
#   '2020-02-01',
#   '2020-03-01',
#   '2020-04-01',
#   '2020-05-01',
#   '2020-06-01',
#   '2020-07-01',
#   '2020-08-01',
#   '2020-09-01',
#   '2020-10-01',
#   '2020-11-01',
#   '2020-12-01',
#   '2021-01-01',
#   '2021-02-01',
#   '2021-03-01',
#   '2021-04-01',
#   '2021-05-01',
#   '2021-06-01',
#   '2021-07-01',
#   '2021-08-01',
#   '2021-09-01',
#   '2021-10-01',
#   '2021-11-01',
#   '2021-12-01',
#   '2022-01-01',
#   '2022-02-01',
#   '2022-03-01',
#   '2022-04-01'],
#  'rate': [0.62,
#   0.35,
#   0.25,
#   2.0,
#   4.64,
#   3.88,
#   4.61,
#   5.51,
#   5.42,
#   4.32,
#   4.07,
#   4.75,
#   5.28,
#   5.5,
#   5.55,
#   4.99,
#   5.28,
#   3.87,
#   2.47,
#   3.37,
#   3.63,
#   3.4,
#   3.15,
#   2.65,
#   4.0,
#   5.65,
#   5.89,
#   6.24]}

# %%
as_time = list(as_data['case_month'])

# %%
as_value = list(as_data['rate'])

# %%
as_L = (
    Line()
    .add_xaxis(as_time)
    .add_yaxis("Asymptomatic Rate (%) ", as_value)
    .set_global_opts(
        xaxis_opts={
            'type':'category',
            'boundaryGap':'false',
        },
        yaxis_opts={
            'type': 'value'
        },
        tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross"),
    )
)

# %%
as_L.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d4ddae132eba4aa4aa2c57350d1a4773" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d4ddae132eba4aa4aa2c57350d1a4773 = echarts.init(
#                     document.getElementById('d4ddae132eba4aa4aa2c57350d1a4773'), 'white', {renderer: 'canvas'});
#                 var option_d4ddae132eba4aa4aa2c57350d1a4773 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...
